# %%
# 객체 생성 코드
# 생성자 호출
cities = list()     # cities = []
season = tuple(["봄", "여름", "가을", "겨울"])  # season = ("봄", "여름", "가을", "겨울")
member = dict()     # member = {}

# %%
print(len([1,2,3]))
print(max(1, 10))
print(min)
