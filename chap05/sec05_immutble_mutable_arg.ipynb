# %%
def fun1(param: int) -> None:
    param = 10
    
def fun2(param: list) -> None:
    param[0] = 10

# %%
# immutable
var1 = 5
fun1(var1)
print("var1:", var1)
# Out:
# var1: 5

# %%
# mutable
var2 = [1, 2, 3]
fun2(var2)
print(var2)
# Out:
# [10, 2, 3]
