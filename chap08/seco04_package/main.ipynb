# %%
import mypack.module1
import mypack.module2
import mypack.module3

mypack.module1.fun()
mypack.module2.fun()
mypack.module3.fun()
# Out:
# mypack/module1/fun() 실행
# mypack/module2/fun() 실행
# mypack/module3/fun() 실행

# %%
from mypack import module1, module2, module3

module1.fun()
module2.fun()
module3.fun()
# Out:
# mypack/module1/fun() 실행
# mypack/module2/fun() 실행
# mypack/module3/fun() 실행

# %%
from mypack import module1, module2, module3
# from mypack import * # 패키지로부터 모든 모듈을 *로 가져올 수는 없음

module1.fun()
module2.fun()
module3.fun()
# Out:
# mypack/module1/fun() 실행
# mypack/module2/fun() 실행
# mypack/module3/fun() 실행

# %%
# __init__.py에 __all__ 리스트를 작성할 경우
