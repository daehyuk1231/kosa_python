# %%
grade= ( 1, 2, 3, 4, 5 )
season = ( "봄", "여름", "가을", "겨울" )
day = ( "월", "화", "수", "목", "금", "토" )

print(grade, f"요소수: {len(grade)}")
print(season, f"요소수: {len(season)}")
print(day, f"요소수: {len(day)}")
# Out:
# (1, 2, 3, 4, 5) 요소수: 5
# ('봄', '여름', '가을', '겨울') 요소수: 4
# ('월', '화', '수', '목', '금', '토') 요소수: 6

# %%
grade= 1, 2, 3, 4, 5
season = "봄", "여름", "가을", "겨울"
day = "월", "화", "수", "목", "금", "토"

print(grade, f"요소수: {len(grade)}")
print(season, f"요소수: {len(season)}")
print(day, f"요소수: {len(day)}")
# Out:
# (1, 2, 3, 4, 5) 요소수: 5
# ('봄', '여름', '가을', '겨울') 요소수: 4
# ('월', '화', '수', '목', '금', '토') 요소수: 6

# %%
grade: tuple[int, ...] = ( 1, 2, 3, 4, 5 )
season: tuple[str, ...] = ( "봄", "여름", "가을", "겨울" )

print(grade, f"요소수: {len(grade)}")
print(season, f"요소수: {len(season)}")

person: tuple[str, int] = ("홍길동", 30)
# Out:
# (1, 2, 3, 4, 5) 요소수: 5
# ('봄', '여름', '가을', '겨울') 요소수: 4

# %%
person: tuple[str, int] = ("홍길동", 30)

name = person[0]
age = person[1]

name, age = person
print(name)
print(age)
# Out:
# 홍길동
# 30

# %%
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)

tuple3 = tuple1 + tuple2
print(tuple3)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
names = ["홍길동", "홍삼원", "홍길남"]

for index, value in enumerate(names):
    print(index, value)
