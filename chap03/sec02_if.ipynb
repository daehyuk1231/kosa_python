# %%
ssn: str = "123456-4325673"

sex: int = int(ssn[7])

if sex == 1 or sex == 3:
    print("한국 태생 남자입니다.")
elif sex == 2:
    print("1900년대 한국 태생 여자입니다.")
elif sex == 4:
    print("2000년대 한국 태생 여자입니다.")
else:
    print("한국에서 태어나지 않았습니다.")
