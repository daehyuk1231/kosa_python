# %%
# 변수 선언
name = "홍길동"
job = '도적'
age = 25
length = 1.5

# %%
a = 8
b = 8
c = 8

# %%
a, b, c = 5, "파이썬", True

# %%
# 파이썬의 모든 변수는 번지를 가지는 참조 변수
# 아직 번지가 없다는 뜻에서 None을 대입할 수 있음
변수 = None

# %%
# 변수 이름
# 1) 모두 소문자가 관례
# 2) 다른 단어와 연결할 때 _ 사용
is_femail = True
mathScore = 90

# %%
# 클래스 이름일 경우는 캐멀 스타일로 작성
class Member:
    pass

class MemberService:
    pass
