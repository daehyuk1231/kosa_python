# %%
num1 = 3
num2 = 5
result = (num1 + 
          num2)
print(result)

# %%
str1 = "Python "
str2 = "Programming"

result = str1 + str2
print(result)

result = "Python " "Programming"
print(result)

result = ("Python "
          "Programming")
print(result)

# %%
name = "홍길동"
age = 30
result = name + "님의 나이는 " + str(age) + "입니다."
print(result)

result = f"{name}님의 나이는 {age}입니다."
print(result)

result = (f"{name}님의 나이는 " 
          f"{age}입니다.")
print(result)
# Out:
# 홍길동님의 나이는 30입니다.
