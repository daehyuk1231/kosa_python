# %%
str1 = "3.54"
# int1 = int(str) # x

# 방법1
int1 = int(float(str1)) # 버림
print(int1)

# 방법2
int2 = round(float(str1)) # 반올림
print(int2)
# Out:
# 3
# 4

# %%
str2 = "3.14759"
float2 = round(float(str2), 2)
print(float2)
# Out:
# 3.15

# %%
print(bool("True"))
# print(bool("False"))
print(eval("False"))
print(bool(""))
print(bool(0))
print(bool(None))
print(bool([])) # 요소가 없는 리스트
print(bool(())) # 요소가 없는 튜플
print(bool({})) # 요소가 없는 딕셔너리

var = None
if not var:
    print("암시적 False")
# Out:
# True
# True
# False
# False
# False
# False
# False
# False
# 암시적 False
