# %%
name: str = "홍길동"
print(name)
# Out:
# 5

# %%
from typing import Any


age: int = 30
height: float = 175.5
is_active: bool = True

value: Any = "홍길동"
value: Any = 10
value: Any = True

# %%
name1: str # 필수 값
name2: str | None = None # 옵션 값
