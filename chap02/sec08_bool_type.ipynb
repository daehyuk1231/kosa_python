# %% [markdown]
# - 비교 연산

# %%
num1 = 5
num2 = 10

print(num1 == num2) # 값 비교
print(num1 != num2) # 값 비교
# Out:
# False
# True

# %% [markdown]
# - 논리 연산

# %%
print(num1 > 3 and num2 < 10)
print(num1 > 3 or num2 < 10)
print(not num1 > 3)
# Out:
# False
# True
# False

# %%
str1 = "abc"
str2 = "Abc"

print(str1 == str2)
print(str1 != str2)
# Out:
# False
# True
