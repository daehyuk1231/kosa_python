# %%
result = 10 / 4
print(result)
# Out:
# 2.5

# %%
result = 10**4
print(result)
# Out:
# 10000

# %%
result = 10 // 4
print(result)

# %%
result = 10 % 4
print(result)
# Out:
# 2

# %%
result = 10
result **= 5
print(result)

# %%
var1 = 100
var2 = 200
print(var1 == var2)
print("var1번지:", id(var1))
print("var2번지:", id(var2))
# Out:
# False
# var1번지: 4334497792
# var2번지: 4334500992

# %%
# 동등 비교(값 비교)
print(var1 == var2)

# 번지 비교
print(var1 is var2)
# Out:
# False
# False
